# %%
import os
import glob

# %%
filenames=glob.glob("\\RETROPIE\roms\snes\*.zip")
print(filenames)
for name in filenames:
    if("Japan" in name):
        os.remove(name)
        print(name+" eliminado\n")
# Out:
# []
